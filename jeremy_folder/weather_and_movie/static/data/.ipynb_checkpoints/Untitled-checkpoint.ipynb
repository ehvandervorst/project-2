# %%
import pandas as pd

from sodapy import Socrata

# %%
client = Socrata("data.cityofnewyork.us", "w5ANkINfDguTjEbedyzkLA1HW")

results = client.get("5uac-w243", limit=2000)

crime_df = pd.DataFrame.from_records(results)
crime_df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   cmplnt_num addr_pct_cd    boro_nm             cmplnt_fr_dt cmplnt_fr_tm  \
# 0  797931560          33  MANHATTAN  2020-09-16T00:00:00.000     00:30:00
# 1  664557183          32  MANHATTAN  2020-06-24T00:00:00.000     21:20:00
# 2  453437883          47      BRONX  2020-09-28T00:00:00.000     20:00:00
# 3  949043828          43      BRONX  2020-07-26T00:00:00.000     01:08:00
# 4  604509546          14  MANHATTAN  2020-09-26T00:00:00.000     19:30:00
#
#   crm_atpt_cptd_cd jurisdiction_code        juris_desc ky_cd   law_cat_cd  \
# 0        COMPLETED               0.0  N.Y. POLICE DEPT   112       FELONY
# 1        COMPLETED               0.0  N.Y. POLICE DEPT   344  MISDEMEANOR
# 2        COMPLETED               0.0  N.Y. POLICE DEPT   105       FELONY
# 3        COMPLETED               0.0  N.Y. POLICE DEPT   126       FELONY
# ...

# %%
crime_df_filtered = crime_df[["rpt_dt", "addr_pct_cd", "ofns_desc", "loc_of_occur_desc", "prem_typ_desc", "lat_lon"]].copy()

# %%
crime_df_filtered
# Out:
#                        rpt_dt addr_pct_cd                      ofns_desc  \
# 0     2020-09-30T00:00:00.000          33                    THEFT-FRAUD
# 1     2020-06-24T00:00:00.000          32   ASSAULT 3 & RELATED OFFENSES
# 2     2020-09-29T00:00:00.000          47                        ROBBERY
# 3     2020-09-28T00:00:00.000          43        MISCELLANEOUS PENAL LAW
# 4     2020-09-27T00:00:00.000          14                  PETIT LARCENY
# ...                       ...         ...                            ...
# 1995  2020-09-22T00:00:00.000          34                        ROBBERY
# 1996  2020-09-27T00:00:00.000          60                  PETIT LARCENY
# 1997  2020-09-28T00:00:00.000           1  OFF. AGNST PUB ORD SENSBLTY &
# 1998  2020-09-29T00:00:00.000          19                  PETIT LARCENY
# 1999  2020-09-29T00:00:00.000          19                  GRAND LARCENY
#
#      loc_of_occur_desc           prem_typ_desc  \
# ...

# %%
crime_df_filtered["rpt_dt"] = crime_df_filtered["rpt_dt"].str.split("T")[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-24ec5842bf38> in <module>
# ----> 1 crime_df_filtered["rpt_dt"] = crime_df_filtered["rpt_dt"].str.split("T")[0]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
# ...
