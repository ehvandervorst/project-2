# %%
import pandas as pd

# %%
weather_df = pd.read_csv("nyc_weather_5_years.csv")
weather_df
# Out:
#           STATION                              NAME        DATE  PRCP  SNOW  \
# 0     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2015-01-01  0.00   0.0
# 1     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2015-01-02  0.00   0.0
# 2     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2015-01-03  0.94   0.0
# 3     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2015-01-04  0.47   0.0
# 4     USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2015-01-05  0.00   0.0
# ...           ...                               ...         ...   ...   ...
# 2184  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-12-24  0.12   0.0
# 2185  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-12-25  0.59   0.0
# 2186  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-12-26  0.00   0.0
# 2187  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-12-27  0.00   NaN
# 2188  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2020-12-28   NaN   NaN
#
#       SNWD  TAVG
# 0      0.0    33
# 1      0.0    39
# ...

# %%
weather_df["NAME"].unique()
# Out:
# array(['JFK INTERNATIONAL AIRPORT, NY US'], dtype=object)
