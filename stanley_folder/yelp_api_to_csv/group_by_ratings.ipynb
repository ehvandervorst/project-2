# %% [markdown]
# # Combining API call results
#
# * Grabbing the two CSVs because made two different calls.
# * Filtering down the data to the top 25% restaurants open.

# %%
import pandas as pd

# %%
csv_path = 'surrounding_nyc_yelp_dataset_nyc.csv'
df = pd.read_csv(csv_path, encoding='utf-8')

# %%
csv_path2 = 'manhattan_df.csv'
df2 = pd.read_csv(csv_path2, encoding='utf-8')

# %%
len(df2)
# Out:
# 860

# %%
out = df.append(df2)

# %%
len(out)
# Out:
# 2122

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1262 entries, 0 to 1261
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1262 non-null   object
#  1   alias             1262 non-null   object
#  2   name              1262 non-null   object
#  3   image_url         1260 non-null   object
#  4   is_closed         1262 non-null   bool
#  5   url               1262 non-null   object
#  6   review_count      1262 non-null   int64
#  7   categories        1262 non-null   object
#  8   rating            1262 non-null   float64
#  9   coordinates       1262 non-null   object
#  10  transactions      1262 non-null   object
#  11  price             1082 non-null   object
#  12  location          1234 non-null   object
#  13  phone             1207 non-null   object
#  14  display_phone     1235 non-null   object
#  15  distance          1094 non-null   object
# ...

# %%
out.describe()
# Out:
#        review_count       rating     latitude    longitude
# count   2122.000000  2122.000000  2122.000000  2122.000000
# mean     322.562677     4.210179    40.734451   -73.934721
# std      622.140033     0.456634     0.078207     0.089385
# min        1.000000     1.500000    40.484090   -74.280340
# 25%       42.000000     4.000000    40.686070   -73.987523
# 50%      125.000000     4.000000    40.742528   -73.948441
# 75%      307.000000     4.500000    40.781226   -73.894899
# max    10008.000000     5.000000    40.959701   -73.647551

# %%
newdf = out.loc[out['rating'] >= 4.5, :]

# %%
newdf
# Out:
#                           id                                         alias  \
# 0     b6jOwyX4iaagw8YjXqq1sA                      antonios-trattoria-bronx
# 3     brE98UK0rJf7cZE3aPrI4A                          bronx-bites-new-york
# 11    zQjaTAxYSKpNNj0F4kgjXQ                        chicken-ranch-new-york
# 12    NNvdMOswZuJ0UUtpP1ievw      casa-della-mozzarella-italian-deli-bronx
# 13    59hEst-eXa_psEtiZMLU6A                     joes-italian-deli-bronx-3
# ...                      ...                                           ...
# 1246  7YJxZAvMxB-oVZfHAuvBmw          lakruwana-restaurant-staten-island-2
# 1247  LV_DKhthhOYbZF-nHvzEyQ  panaderia-la-mixteca-poblana-staten-island-2
# 1248  YOOZjCcC4s1MOBtFsaMB8w                    the-richmond-staten-island
# 1252  AICctWjO4hFXfVQpJukEyw             tri-lounge-and-cafe-staten-island
# 1260  22QsJuEb7zBqy6J8xDe8gw                       la-brujeria-jersey-city
#
#                                     name  \
# ...

# %%
len(newdf)
# Out:
# 579

# %%
newdf = newdf.loc[newdf['review_count'] > 307, :]

# %%
len(newdf)
# Out:
# 169

# %%
newdf.to_csv('parsed_nyc_yelp_dataset_4_stars_75_percentile.csv', index=False, header=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                257 non-null    object
#  1   alias             257 non-null    object
#  2   name              257 non-null    object
#  3   image_url         257 non-null    object
#  4   is_closed         257 non-null    bool
#  5   url               257 non-null    object
#  6   review_count      257 non-null    int64
#  7   categories        257 non-null    object
#  8   rating            257 non-null    float64
#  9   coordinates       257 non-null    object
#  10  transactions      257 non-null    object
#  11  price             228 non-null    object
#  12  location          256 non-null    object
#  13  phone             247 non-null    object
#  14  display_phone     248 non-null    object
#  15  distance          243 non-null    object
# ...
